# %% [markdown]
# <h1 style="text-align: center;"><a title="Data Science-AIMS-Cmr-2021-22">Quiz 1: Dataclasses (Repeat) </h1>
#
# **Instructor:**
#
# * Rockefeller

# %% [markdown]
# **James Wandiya**

# %% [markdown]
# # **<span style="color:red">Score: 10/ 20 </span>**

# %% [markdown]
# **Contexte:** Vous modélisez des données pour une application africaine. Utilisez les dataclasses pour représenter les entités suivantes.
#
# ---
#
# ### **Exercice 1: Centrafrique - Secteur de la Santé** (5 points)
#
# **Context:** You are modeling data for an African application. Use dataclasses to represent the following entities.
#
# ---
#
# ### **Exercise 1: Central African Republic - Health Sector** (5 points)
#
# *Text:* The Bangui Community Hospital has 150 beds and employs 45 nurses. Dr. Marie Nzapa, 38 years old, has worked there as a surgeon for 12 years with a specialization in general surgery. The Friendship Hospital has 200 beds, employs 60 nurses, and Dr. Jean Koyamba, 52 years old, has been working there as a pediatrician for 25 years.

# %% [markdown]
# ## 1. D'après le texte ci-haut, quels sont les attributs qui peuvent être utilisés pour modeliser  la representation d'un `Hopital`.
# ## 1. According to the text above, what are the attributes that can be used to model the representation of a `Hospital`.

# %% [markdown]
# **<span style="color:red">Score: 1/ 1 </span>**

# %%
from dataclasses import dataclass

@dataclass
class Hospital:
    name: str
    number_of_beds: int
    number_of_nurses: int

# %% [markdown]
# ## 2. D'après le texte ci-haut, quels sont les attributs qui peuvent être utilisés pour modeliser  la representation d'un `Medecin`.
#
#
# ## 2. According to the text above, what are the attributes that can be used to model the representation of a `Doctor`.

# %% [markdown]
# **<span style="color:red">Score: 1/ 1 </span>**

# %%
name: str 
specialty: str 
years_of_experience: int
hospital: str 
role: str(optional)

# %% [markdown]
# ## 3. A partir des attributs que vous avez listés, Créez une dataclasse `Hopital` avec les attributs appropriés.
#
# ## 3. From the attributes you have listed, create a dataclass `Hospital` with the appropriate attributes.

# %% [markdown]
# **<span style="color:red">Score: 0/ 2 </span>**

# %%
bangui_community = Hospital(
    name="Bangui Community Hospital",
    location="Bangui",
    bed_count=150,
    nurse_count=45,
    doctors=["Dr. Marie Nzapa"],
    specialties=["General Surgery"]
)

friendship = Hospital(
    name="Friendship Hospital",
    location="Bangui", 
    bed_count=200,
    nurse_count=60,
    doctors=["Dr. Jean Koyamba"],
    specialties=["Pediatrics"]
)

# %% [markdown]
# ## 4. Créez une dataclasse `Medecin` avec les attributs appropriés
#
# ## 4. Create a `Medecin` data class with the appropriate attributes

# %% [markdown]
#  **<span style="color:red">Score: 0/ 2 </span>**

# %%
dr_marie = Medecin(
    name="Dr. Marie Nzapa",
    age=38,
    specialty="General Surgery",
    years_of_experience=12,
    hospital="Bangui Community Hospital"
)

dr_jean = Medecin(
    name="Dr. Jean Koyamba",
    age=52,
    specialty="Pediatrics", 
    years_of_experience=25,
    hospital="Friendship Hospital"
)

# %% [markdown]
# ## 5. A partir du `dataclass Hopital`  que vous avez créé, generer les instances pour les deux hôpitaux
#
# ## 5. From the `Hopital` dataclass that you created, generate the instances for the two hospitals

# %% [markdown]
# **<span style="color:red">Score: 2/ 2 </span>**

# %%
hopital_communautaire = Hopital(
    nom="Hôpital Communautaire de Bangui",
    lieu="Bangui",
    nombre_lits=150,
    nombre_infirmiers=45,
    docteurs=["Dr. Marie Nzapa"],
    specialites=["Chirurgie Générale"]
)

hopital_amitie = Hopital(
    nom="Hôpital de l'Amitié",
    lieu="Bangui",
    nombre_lits=200,
    nombre_infirmiers=60,
    docteurs=["Dr. Jean Koyamba"],
    specialites=["Pédiatrie"]
)

# %% [markdown]
# ## 6. A partir du `dataclass Medecin`  que vous avez créé, generer les instances pour les deux médécins.
#
#
# ## 6. From the `Medecin` dataclass you created, generate instances for the two doctors.

# %% [markdown]
#  **<span style="color:red">Score: 2/ 2 </span>**

# %%
dr_marie = Doctor(
    name="Dr. Marie Nzapa",
    age=38,
    specialty="General Surgery",
    years_of_experience=12,
    hospital="Bangui Community Hospital"
)

dr_jean = Doctor(
    name="Dr. Jean Koyamba",
    age=52,
    specialty="Pediatrics",
    years_of_experience=25,
    hospital="Friendship Hospital"
)

# %% [markdown]
# ### **Exercice 2: Djibouti - Secteur du Commerce** (5 points)
#
# *Texte:* Le port autonome de Djibouti traite 850 000 conteneurs par an et s'étend sur 1590 hectares avec 15 quais d'accostage. La société de transport "Boreh Logistics" possède une flotte de 42 camions et effectue en moyenne 320 livraisons par mois vers l'Éthiopie. Son directeur, Ahmed Hassan, gère 28 employés.
#
#
#
# ### **Exercise 2: Djibouti - Trade Sector** (5 points)
#
# *Text:* The Djibouti Autonomous Port handles 850,000 containers per year and covers 1,590 hectares with 15 docking quays. The transport company "Boreh Logistics" has a fleet of 42 trucks and makes an average of 320 deliveries per month to Ethiopia. Its director, Ahmed Hassan, manages 28 employees.

# %% [markdown]
# ## 1. D'après le texte ci-haut, quels sont les attributs qui peuvent être utilisés pour modeliser  la representation d'un `Port`.
#
#
# ## 1. According to the text above, what are the attributes that can be used to model the representation of a `Port`.

# %% [markdown]
#  **<span style="color:red">Score: 1/ 1 </span>**

# %%
from dataclasses import dataclass

@dataclass
class Port:
    name: str
    containers_per_year: int
    area_hectares: float
    docking_quays: int

# Create instance for Djibouti Autonomous Port
djibouti_port = Port(
    name="Djibouti Autonomous Port",
    containers_per_year=850000,
    area_hectares=1590.0,
    docking_quays=15
)

# %% [markdown]
# ## 2. D'après le texte ci-haut, quels sont les attributs qui peuvent être utilisés pour modeliser  la representation d'une `EntrepriseTransport`.
#
#
# ## 2. According to the text above, what attributes can be used to model the representation of a `TransportCompany`.

# %% [markdown]
#  **<span style="color:red">Score: 1/ 1 </span>**

# %%
class TransportCompany:
    name: str
    truck_fleet_size: int
    monthly_deliveries: int
    delivery_destination: str
    employee_count: int
    director_name: str

boreh_logistics = TransportCompany(
    name="Boreh Logistics",
    truck_fleet_size=42,
    monthly_deliveries=320,
    delivery_destination="Ethiopia",
    employee_count=28,
    director_name="Ahmed Hassan"
)

# %% [markdown]
# ## 3. Créez une dataclasse `Port` avec les attributs que vous avez listés pour modeliser la representation d'un port.
# ## 3. Create a `Port` data class with the attributes you listed to model the representation of a port.

# %% [markdown]
# **<span style="color:red">Score: 2/ 2 </span>**

# %%
from dataclasses import dataclass
@dataclass
class Port:
    name: str
    containers_per_year: int
    area_hectares: float
    docking_quays: int

djibouti_port = Port(
    name="Djibouti Autonomous Port",
    containers_per_year=850000,
    area_hectares=1590.0,
    docking_quays=15
)

# %% [markdown]
# ## 4. Créez une dataclasse `EntrepriseTransport` avec les attributs que vous avez listés pour modeliser la representation d'une entreprise de transport.
#
#
# ## 4. Create a dataclass `EntrepriseTransport` with the attributes you listed to model the representation of a transport company.

# %% [markdown]
# ## 5. A partir du `dataclass Port` que vous avez créé, generer un instance de cette classe pour representer le Port de DJibouti

# %% [markdown]
# ## 6.  A partir du `dataclass EntrepriseTransport` que vous avez créé, generer un instance de cette classe pour representer la société `Boreh Logisitic`.
